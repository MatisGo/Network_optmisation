# %% [markdown]
# What to do:
# 1. Define the best temporary location for each store => DONE
# 2. Take the code bellow and replace the randomisation by the exel files (only 2 Weeks). => DONE
# 3. Run the code and get the loading results displayed in a graph => DONE
# 4. Loop the Supermaket locations (4 loops) to find the best location for each of them by calculating the average minimum load of the average of all the lines. => ToDo
# 5. Step 2 Done!

# %%
import sys
import pandapower as pp
import pandapower.networks as nw
import pandas as pd
import nbformat
import matplotlib.pyplot as plt
from pandapower.plotting.plotly import simple_plotly
from pandapower.plotting.plotly import pf_res_plotly
import copy
import pandapower as pp
from pandapower.plotting.plotly import simple_plotly
from pandapower.plotting.plotly import pf_res_plotly


net = pp.networks.create_cigre_network_mv(with_der=False)


net.load['p_mw']= net.load['p_mw'] / 2
net.load['q_mvar']= net.load['q_mvar'] / 2

pp.runpp(net)
print(net.load)

# print(net.res_bus)
# print(net.res_line.loading_percent)
# print(net.res_trafo.loading_percent)

# simple_plotly(net)
# pf_res_plotly(net)
# Out:
#          name  bus      p_mw    q_mvar  const_z_percent  const_i_percent  \
# 0     Load R1    1  7.497000  1.522331              0.0              0.0
# 1     Load R3    3  0.138225  0.034642              0.0              0.0
# 2     Load R4    4  0.215825  0.054091              0.0              0.0
# 3     Load R5    5  0.363750  0.091164              0.0              0.0
# 4     Load R6    6  0.274025  0.068677              0.0              0.0
# 5     Load R8    8  0.293425  0.073539              0.0              0.0
# 6    Load R10   10  0.237650  0.059561              0.0              0.0
# 7    Load R11   11  0.164900  0.041328              0.0              0.0
# 8    Load R12   12  7.497000  1.522331              0.0              0.0
# 9    Load R14   14  0.104275  0.026134              0.0              0.0
# 10   Load CI1    1  2.422500  0.796237              0.0              0.0
# 11   Load CI3    3  0.112625  0.069799              0.0              0.0
# 12   Load CI7    7  0.038250  0.023705              0.0              0.0
# 13   Load CI9    9  0.286875  0.177789              0.0              0.0
# 14  Load CI10   10  0.034000  0.021071              0.0              0.0
# 15  Load CI12   12  2.508000  0.824340              0.0              0.0
# 16  Load CI13   13  0.017000  0.010536              0.0              0.0
# 17  Load CI14   14  0.165750  0.102723              0.0              0.0
#
#     sn_mva  scaling  in_service type
# 0   15.300      1.0        True  wye
# 1    0.285      1.0        True  wye
# 2    0.445      1.0        True  wye
# 3    0.750      1.0        True  wye
# 4    0.565      1.0        True  wye
# 5    0.605      1.0        True  wye
# 6    0.490      1.0        True  wye
# 7    0.340      1.0        True  wye
# 8   15.300      1.0        True  wye
# 9    0.215      1.0        True  wye
# 10   5.100      1.0        True  wye
# 11   0.265      1.0        True  wye
# 12   0.090      1.0        True  wye
# 13   0.675      1.0        True  wye
# 14   0.080      1.0        True  wye
# 15   5.280      1.0        True  wye
# 16   0.040      1.0        True  wye
# 17   0.390      1.0        True  wye

# %% [markdown]
# 1. Best temporary locations for each store:
# ICA=> Average 1211 kW/h
# Mathem => Average 787 kW/h
# Postnord => Average 1000 kW/h
# Airmee=> Average 317 kW/h
#
# With the Graph Visualisation, the best locations for new loads seems to be Bus 6,8,14,4 for the best repartition of power load
# Let's define
# ICA => Bus 8
# Mathem => Bus 6
# Postnord => 14
# Airmee => 4

# %%
def check_within_limits(net_check, vmax=1.1, vmin=0.9, line_loading_max=100): 
    
    if net_check.res_bus.vm_pu.max() > vmax: return False

    if net_check.res_bus.vm_pu.min() < vmin: return False

    if net_check.res_line.loading_percent.max() > line_loading_max: return False

    else : return True

# %%
# ------------- 1. create network and apply initial change -------------
net0 = nw.create_cigre_network_mv(with_der=False)

net0.switch["closed"] = True  # close the tie switch

# scale down loads
net0.load['p_mw'] = net0.load['p_mw'] / 2.0
net0.load['q_mvar'] = net0.load['q_mvar'] / 2.0

base_loads = net0.load['p_mw'].copy()

# ------------- 2. Read the Excel File -------------
file_path = "Load_profiles_Freight transports.xlsx"
load_profile = pd.read_excel(file_path)

load_profile["Datetime"] = pd.to_datetime(load_profile["Date"].astype(str) + " " + load_profile["Time"].astype(str))
load_profile = load_profile.set_index("Datetime")

# Only keep the 4 shop columns
shops = ["ICA", "Mathem", "Postnord", "Airmee"]
load_profile = load_profile[shops]

# ------------- 3. Mapping shops to buses -------------



def find_bus_indice(net_provided, shop_name, shop_to_bus):
    current_best_case_max_of_max = sys.float_info.max # initialize with a large number
    current_best_shop_to_bus = None
    current_best_res_lines = None
    current_best_net = None
    for bus_idx in range(2,15):
        if bus_idx != 12:
            
            net = copy.deepcopy(net_provided)

            shop_to_bus[shop_name] = bus_idx

            print(f"Trying mapping: {shop_to_bus}")        



            # ------------- 4. results DataFrame for line loading -------------
            line_indices = list(net.line.index)
            col_names = [f"line_{i}" for i in line_indices]
            res_lines = pd.DataFrame(index=load_profile.index, columns=col_names, dtype=float)


            # ------------- 5. simulation loop -------------
            for ts in load_profile.index:

                net.load['p_mw'] = base_loads.copy()  # reset to base loads

                # assign each shop load to its bus
                for shop, bus in shop_to_bus.items():
                    # locate the load element connected to that bus
                    idx = net.load[net.load.bus == bus].index
                    if not idx.empty:
                        print(net.load.bus)
                        add_mw = load_profile.at[ts, shop] / 1000.0  # Change unit kW to MW
                        #print("before add", net.load.at[idx[0], 'p_mw'])
                        net.load.at[idx[0], 'p_mw'] = add_mw + net.load.at[idx[0], 'p_mw']
                        #print(f"At {ts}, added {add_mw} MW to bus {bus} for shop {shop}. New load: {net.load.at[idx[0], 'p_mw']} MW at index {idx[0]}")
                    else :
                        pp.create_load(net, bus, p_mw=load_profile.at[ts, shop] / 1000.0, q_mvar=0.0)

                #print(net.load.at[12, 'p_mw'])    
                # run power flow
                try:
                    pp.runpp(net, calculate_voltage_angles=False)
                    
                    loading = net.res_line.loading_percent
                    #print(loading)
                    
                    for li in line_indices:
                        res_lines.at[ts, f"line_{li}"] = loading.at[li]
                        
                        

                    
                except Exception as e:
                    print(f"Power flow failed at {ts}: {e}")
                    res_lines.loc[ts, :] = np.nan

            max_of_max = res_lines.max().max()
            if max_of_max < current_best_case_max_of_max and check_within_limits(net, line_loading_max=110):
                current_best_case_max_of_max = max_of_max
                current_best_shop_to_bus = shop_to_bus.copy()
                current_best_res_lines = res_lines.copy()  
                current_best_net = copy.deepcopy(net)
                print("New best max of max line loading:", current_best_case_max_of_max)
    return current_best_shop_to_bus, current_best_res_lines, current_best_net, current_best_case_max_of_max
        
best_case_max_of_max = sys.float_info.max # initialize with a large number
best_shop_to_bus = None
best_res_lines = None
best_net = None
shop_to_bus = {}

for shop in shops:
    print(f"Optimizing location for shop: {shop}")
    best_shop_to_bus, best_res_lines, best_net, best_case_max_of_max = find_bus_indice(net0, shop, shop_to_bus)
    shop_to_bus = best_shop_to_bus.copy()  # update for the next shop
    print(f"Best location for {shop} so far: {best_shop_to_bus} with max line loading: {best_case_max_of_max}")
    
                
                    
if best_shop_to_bus is None:
    print("No valid shop-to-bus mapping found that satisfies the constraints.")
                    
else :
    # ------------- 6. summary Average Load Stats -------------
    print("Per-line max loading (%) over 2 weeks:")
    print(best_res_lines.max().sort_values(ascending=False))

    # ------------- 7. plot the Load of each line -------------
    plt.figure(figsize=(14, 6))

    for col in best_res_lines.columns:
        plt.plot(best_res_lines.index, best_res_lines[col], linewidth=0.9, label=col)

    plt.xlabel("Time")
    plt.ylabel("Line loading (%)")
    plt.title("Line loading percent — 2 weeks (hourly)")
    plt.grid(alpha=0.3)

    # place legend outside the plot for readability
    plt.legend(loc="center left", bbox_to_anchor=(1, 0.5), ncol=1, fontsize=8)

    plt.tight_layout()
    plt.show()

    simple_plotly(best_net)
    pf_res_plotly(best_net)



    # ------------- 10. save results -------------
    # res_lines.to_csv("line_loading_2weeks_hourly.csv")
    # print("Saved CSV: line_loading_2weeks_hourly.csv")
# Out:
# Optimizing location for shop: ICA
# Trying mapping: {'ICA': 2}
# 0      1
# 1      3
# 2      4
# 3      5
# 4      6
# 5      8
# 6     10
# 7     11
# 8     12
# 9     14
# 10     1
# 11     3
# 12     7
# 13     9
# 14    10
# 15    12
# 16    13
# 17    14
# 18     2
# Name: bus, dtype: uint32
# c:\Users\PC\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandapower\pf\create_jacobian.py:27: RuntimeWarning: invalid value encountered in divide
#   dVm_x, dVa_x = dSbus_dV_numba_sparse(Ybus.data, Ybus.indptr, Ybus.indices, V, V / abs(V), Ibus)
# c:\Users\PC\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandapower\pypower\newtonpf.py:441: MatrixRankWarning: Matrix is exactly singular
#   dx = -1 * spsolve(J, F, permc_spec=permc_spec, use_umfpack=use_umfpack)
# Power flow failed at 2026-01-01 01:00:00+01:00: Power Flow nr did not converge after 10 iterations!
# ---------------------------------------------------------------------------
# LoadflowNotConverged                      Traceback (most recent call last)
# Cell In[3], line 70, in find_bus_indice(net_provided, shop_name, shop_to_bus)
#      69 try:
# ---> 70     pp.runpp(net, calculate_voltage_angles=False)
#      72     loading = net.res_line.loading_percent
#
# File c:\Users\PC\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandapower\run.py:249, in runpp(net, algorithm, calculate_voltage_angles, init, max_iteration, tolerance_mva, trafo_model, trafo_loading, enforce_q_lims, check_connectivity, voltage_depend_loads, consider_line_temperature, run_control, distributed_slack, tdpf, tdpf_delay_s, **kwargs)
#     248 _check_gen_index_and_print_warning_if_high(net)
# --> 249 _powerflow(net, **kwargs)
#
# File c:\Users\PC\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandapower\powerflow.py:70, in _powerflow(net, **kwargs)
#      69 # read the results (=ppci with results) to net
# ---> 70 _ppci_to_net(result, net)
#
# File c:\Users\PC\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandapower\powerflow.py:174, in _ppci_to_net(result, net)
#     173     max_iteration = net["_options"]["max_iteration"]
# --> 174     raise LoadflowNotConverged("Power Flow {0} did not converge after "
#     175                                "{1} iterations!".format(algorithm, max_iteration))
#     176 else:
#
# LoadflowNotConverged: Power Flow nr did not converge after 10 iterations!
#
# During handling of the above exception, another exception occurred:
#
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 102
#     100 for shop in shops:
#     101     print(f"Optimizing location for shop: {shop}")
# --> 102     best_shop_to_bus, best_res_lines, best_net, best_case_max_of_max = find_bus_indice(net0, shop, shop_to_bus)
#     103     shop_to_bus = best_shop_to_bus.copy()  # update for the next shop
#     104     print(f"Best location for {shop} so far: {best_shop_to_bus} with max line loading: {best_case_max_of_max}")
#
# Cell In[3], line 83, in find_bus_indice(net_provided, shop_name, shop_to_bus)
#      81     except Exception as e:
#      82         print(f"Power flow failed at {ts}: {e}")
# ---> 83         res_lines.loc[ts, :] = np.nan
#      85 max_of_max = res_lines.max().max()
#      86 if max_of_max < current_best_case_max_of_max and check_within_limits(net, line_loading_max=110):
#
# NameError: name 'np' is not defined

# %%
print("Best shop to bus mapping:", best_shop_to_bus)
print(best_net.load)
# Out:
# Best shop to bus mapping: {'ICA': 2, 'Mathem': 2, 'Postnord': 2, 'Airmee': 2}
#          name  bus      p_mw    q_mvar  const_z_percent  const_i_percent  \
# 0     Load R1    1  7.497000  1.522331              0.0              0.0
# 1     Load R3    3  0.138225  0.034642              0.0              0.0
# 2     Load R4    4  0.215825  0.054091              0.0              0.0
# 3     Load R5    5  0.363750  0.091164              0.0              0.0
# 4     Load R6    6  0.274025  0.068677              0.0              0.0
# 5     Load R8    8  0.293425  0.073539              0.0              0.0
# 6    Load R10   10  0.237650  0.059561              0.0              0.0
# 7    Load R11   11  0.164900  0.041328              0.0              0.0
# 8    Load R12   12  7.497000  1.522331              0.0              0.0
# 9    Load R14   14  0.104275  0.026134              0.0              0.0
# 10   Load CI1    1  2.422500  0.796237              0.0              0.0
# 11   Load CI3    3  0.112625  0.069799              0.0              0.0
# 12   Load CI7    7  0.038250  0.023705              0.0              0.0
# 13   Load CI9    9  0.286875  0.177789              0.0              0.0
# 14  Load CI10   10  0.034000  0.021071              0.0              0.0
# 15  Load CI12   12  2.508000  0.824340              0.0              0.0
# 16  Load CI13   13  0.017000  0.010536              0.0              0.0
# 17  Load CI14   14  0.165750  0.102723              0.0              0.0
#
#     sn_mva  scaling  in_service type
# 0   15.300      1.0        True  wye
# 1    0.285      1.0        True  wye
# 2    0.445      1.0        True  wye
# 3    0.750      1.0        True  wye
# 4    0.565      1.0        True  wye
# 5    0.605      1.0        True  wye
# 6    0.490      1.0        True  wye
# 7    0.340      1.0        True  wye
# 8   15.300      1.0        True  wye
# 9    0.215      1.0        True  wye
# 10   5.100      1.0        True  wye
# 11   0.265      1.0        True  wye
# 12   0.090      1.0        True  wye
# 13   0.675      1.0        True  wye
# 14   0.080      1.0        True  wye
# 15   5.280      1.0        True  wye
# 16   0.040      1.0        True  wye
# 17   0.390      1.0        True  wye
