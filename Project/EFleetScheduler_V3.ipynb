# %% [markdown]
# <p align="center">
#     <span style="color:chocolate; font-size:2.5em; font-weight:bold;">
#         Schedule Generator of electric LCV
#     </span>
# </p>
#
# <p align="center">
#     <span style="font-size:1.5em; font-weight:bold;">
#         Carolina Gil Ribeiro, Jagruti Thakur
#     </span>
# </p>

# %% [markdown]
# Install efleetschedule package in your environment (only need to run this cell in the first time, after put # in front)

# %%
pip install --upgrade efleetscheduler
# Out:
# Requirement already satisfied: efleetscheduler in c:\users\matis\appdata\local\programs\python\python312\lib\site-packages (1.0.4)
# Requirement already satisfied: matplotlib>=3.3.0 in c:\users\matis\appdata\local\programs\python\python312\lib\site-packages (from efleetscheduler) (3.9.2)
# Requirement already satisfied: numpy>=1.20.0 in c:\users\matis\appdata\local\programs\python\python312\lib\site-packages (from efleetscheduler) (2.1.2)
# Requirement already satisfied: pandas>=1.3.0 in c:\users\matis\appdata\local\programs\python\python312\lib\site-packages (from efleetscheduler) (2.2.3)
# Requirement already satisfied: xlsxwriter>=3.0.0 in c:\users\matis\appdata\local\programs\python\python312\lib\site-packages (from efleetscheduler) (3.2.5)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\matis\appdata\local\programs\python\python312\lib\site-packages (from matplotlib>=3.3.0->efleetscheduler) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\matis\appdata\local\programs\python\python312\lib\site-packages (from matplotlib>=3.3.0->efleetscheduler) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\matis\appdata\local\programs\python\python312\lib\site-packages (from matplotlib>=3.3.0->efleetscheduler) (4.54.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\matis\appdata\local\programs\python\python312\lib\site-packages (from matplotlib>=3.3.0->efleetscheduler) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in c:\users\matis\appdata\local\programs\python\python312\lib\site-packages (from matplotlib>=3.3.0->efleetscheduler) (24.1)
# Requirement already satisfied: pillow>=8 in c:\users\matis\appdata\local\programs\python\python312\lib\site-packages (from matplotlib>=3.3.0->efleetscheduler) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\matis\appdata\local\programs\python\python312\lib\site-packages (from matplotlib>=3.3.0->efleetscheduler) (3.1.4)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\matis\appdata\local\programs\python\python312\lib\site-packages (from matplotlib>=3.3.0->efleetscheduler) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\matis\appdata\local\programs\python\python312\lib\site-packages (from pandas>=1.3.0->efleetscheduler) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\matis\appdata\local\programs\python\python312\lib\site-packages (from pandas>=1.3.0->efleetscheduler) (2024.1)
# Requirement already satisfied: six>=1.5 in c:\users\matis\appdata\local\programs\python\python312\lib\site-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->efleetscheduler) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## 0. Importing dependencies

# %%
import pandas as pd
import numpy as np
import xlsxwriter as xl
import matplotlib.pyplot as plt
import os
from glob import glob
from matplotlib import rcParams
from datetime import datetime
import datetime as dt
import math
from typing import Literal
import time
from matplotlib.ticker import MaxNLocator

import sys
module_path = os.path.abspath(os.path.join(os.getcwd(), '..'))
src_path = os.path.join(module_path, 'src')
if src_path not in sys.path:
	sys.path.append(src_path)

from efleetscheduler.schedule_generator_1 import ScheduleGenerator
from efleetscheduler.schedule_configure import scheduletype, vehicletype, companytype
from efleetscheduler.schedule_generator_2 import generate_schedules
from efleetscheduler.generate_graphs import generate_graphs

project_root = os.path.abspath(os.path.join(os.getcwd(), '..'))

notebook_dir = os.getcwd()

# %% [markdown]
# # <span style="color:chocolate;">1. SCHEDULE GENERATOR MODULE</span>

# %% [markdown]
# <span style="color:green">
#
# ## 1.1 Schedule generator configurations
# </span>

# %% [markdown]
# In this module, the only required input file is the Energy Consumption Factor.
# This factor is used to adjust energy consumption values based on changes in temperature, accounting for environmental and operational variations.
#
# The example uses hourly temperature data from the "Stockholm-Observatorielunden A" measurement station, provided by the Swedish Meteorological and Hydrological Institute (SMHI).
#
# Keep the data file in the same folder as the code

# %%
# environment arguments - adjust settings if necessary
env_config = {"original_seed": 42,  # Seed for RNG - can be set to None so always random (not recommended)
                    
              # settings below if you want to generate new schedules
              "gen_start_date": "2026-01-01 00:00:00",  # New schedule, start date ##CHANGE
              "gen_end_date": "2026-01-14 23:00:00",  # New schedule, end date ##CHANGE
              "freq": "h",  # 'h' means hourly frequency. .
              
              "EVs": 100,  # Number of electric vehicles in the fleet ##CHANGE
                            
              # path to the CSV file with energy consumption factor (the example if for Stockholm 2026)
              # This value can be adjusted to other locations with hourly temperature data
              "consumption_factor_file" : os.path.join(notebook_dir, "Energy_consumption_factor_2026.csv")  #link to the file here
                                         
              }

# %% [markdown]
# <span style="color:green">
#
# ## 1.2. Fleet parameters configurations
#
# </span>

# %% [markdown]
# It is possible to generate diferent types of schedules, adjusting different parameters.
# Schedule configuration includes: Type of schedule (a or b), Type of vehicle (Catefory 1 - Renault and Category 2 - Toyota) and Company type.
#
# New fleet parameters can be defined/created in the file "schedule_configure.py".

# %% [markdown]
# #### Type of Schedule
# Schedules are categorised into two types: Type A, which consists of a continuous schedule, and Type B, which includes breaks. Various parameters are established to facilitate realistic modelling of daily logistics schedules, including mean departure and return times, standard deviations, and allowable time ranges.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Type of vehicle: Small LCV - n_Renault and Large LCV - n_toyota
#
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Company type
# The values related to company type are defined based on the findings of a survey on light goods vehicles in Sweden conducted by Transport Analysis in 2022.
#
# ![image.png](attachment:image.png)
#
# notes: Type of transport is defined as the primary use of the LCV and are described as follows: distribution transport for goods or commodities transports with several stops for loading and unloading along the way; Line haul goods or commodities transports, directly from one place to another;  Crafts and services with goods transports include trips for craft or service vehicle that include goods or merchandise to be used or installed in the work; and crafts and services without goods correspond to craft or service trips without goods or merchandise.
#
# ![image-2.png](attachment:image-2.png)
#
# notes: Commodity groups were formulated in Light Goods Vehicles 2022 survey to capture the type of goods commonly transported identified by the vehicles.

# %% [markdown]
# ### Schedule generator configurations - configuration of your fleet for each company

# %%
# Schedule arguments - adjust settings if necessary

#ICA

ICA_sch_config = {"Vehicles number": 14, ##CHANGE # Number of vehicles in the fleet (You can choose the number of vehicles you want to generate the schedule for, but it needs to be the same has env_config)
              
              "Type of schedule": {"type a": 0, "type b":14, "type c": 0},  ##CHANGE NUMBER OF EV # Type A, which consists of a continuous schedule, and Type B, which includes breaks, going to the distribution terminal durind the day.
              
              #type C is Custom Schedule is when you need to createq your own schedule, and it is defined below.
                            
              # Type C is Custom Schedule that needs to be define here:
              
              "Custom Schedule": {"average departure weekday": 8,  # Average departure time on a weekday in hours (0-23)
                                  "std deviation departure weekday": 1,  # Standard deviation of departure time on a weekday in hours
                                  "average return weekday": 18,  # Average return time on a weekday in hours (0-23)
                                  "std deviation return weekday": 1,  # Standard deviation of return time on a weekday in hours
                                  "average departure weekend": 9,  # Average departure time on a weekend in hours (0-23)
                                  "std deviation departure weekend": 1,  # Standard deviation of departure time on a weekend in hours
                                  "average return weekend": 19,  # Average return time on a weekend in hours (0-23)
                                  "std deviation return weekend": 1,  # Standard deviation of return time on a weekend in hours
                                  "minimum departure": 6,  # Minimum departure time in hours (0-23)
                                  "maximum departure": 11,  # Maximum departure time in hours (0-23)
                                  "minimum return": 18,  # Minimum return time in hours (0-23)
                                  "maximum return": 22  # Maximum return time in hours (0-23)
                                  },
              
              "Type of vehicle": {"Renault": 6, "Toyota": 8},  # Renault or Toyota ##CHANGE COMBINATION
              
              "Company type": companytype.Food, ##CHANGE # Types of company: Distribution, LineHaul, CraftServWithGoods, CraftServWithoutGoods, Food, Mail, Building, Highdistance, Generalcargo, Nogoodsm, Custom
              
              #"Company type":Custom,  # Custom company type, if you want to generate a custom schedule with your own distance and stops parameters
              "Custom Distance": {"average weekday":120,  # Average distance travelled on a weekday in km
                                "average weekend": 70,  # Average distance travelled on a weekend in km 
                                "standard deviation weekday": 15,  # Standard deviation of distance travelled on a weekday in km
                                "standard deviation weekend": 15,  # Standard deviation of distance travelled on a weekend in
                                "min distance": 30,  # Minimum distance travelled in km
                                "max distance": 300,  # Maximum distance travelled in km  
                                "min distance per hour": 1,  # Minimum distance travelled per hour in km
                                "max distance per hour": 50,  # Maximum distance travelled per hour in km
                                "average stops": 30,  # Average number of stops per day
                                "standard deviation stops": 10  # Standard deviation of number of stops per                  
                                },
              
              "Schedule name": 'schedule_ICA' ##CHANGE # Name of the schedule
                }

# %%
# Schedule arguments - adjust settings if necessary

#Mathem

Mathem_sch_config = {"Vehicles number": 24,  ##CHANGE # Number of vehicles in the fleet (You can choose the number of vehicles you want to generate the schedule for, but it needs to be the same has env_config)
              
              "Type of schedule": {"type a": 0, "type b": 24, "type c": 0},  ##CHANGE NUMBER OF EV # Type A, which consists of a continuous schedule, and Type B, which includes breaks, going to the distribution terminal durind the day.
              
              #type C is Custom Schedule is when you need to createq your own schedule, and it is defined below.
                            
              # Type C is Custom Schedule that needs to be define here:
              
              "Custom Schedule": {"average departure weekday": 8,  # Average departure time on a weekday in hours (0-23)
                                  "std deviation departure weekday": 1,  # Standard deviation of departure time on a weekday in hours
                                  "average return weekday": 18,  # Average return time on a weekday in hours (0-23)
                                  "std deviation return weekday": 1,  # Standard deviation of return time on a weekday in hours
                                  "average departure weekend": 9,  # Average departure time on a weekend in hours (0-23)
                                  "std deviation departure weekend": 1,  # Standard deviation of departure time on a weekend in hours
                                  "average return weekend": 19,  # Average return time on a weekend in hours (0-23)
                                  "std deviation return weekend": 1,  # Standard deviation of return time on a weekend in hours
                                  "minimum departure": 6,  # Minimum departure time in hours (0-23)
                                  "maximum departure": 11,  # Maximum departure time in hours (0-23)
                                  "minimum return": 18,  # Minimum return time in hours (0-23)
                                  "maximum return": 22  # Maximum return time in hours (0-23)
                                  },
              
              "Type of vehicle": {"Renault": 6, "Toyota":18},  # Renault or Toyota ##CHANGE COMBINATION
              
              "Company type": companytype.Food, ##CHANGE # Types of company: Distribution, LineHaul, CraftServWithGoods, CraftServWithoutGoods, Food, Mail, Building, Highdistance, Generalcargo, Nogoodsm, Custom
              
              #"Company type":Custom,  # Custom company type, if you want to generate a custom schedule with your own distance and stops parameters
              "Custom Distance": {"average weekday":120,  # Average distance travelled on a weekday in km
                                "average weekend": 70,  # Average distance travelled on a weekend in km 
                                "standard deviation weekday": 15,  # Standard deviation of distance travelled on a weekday in km
                                "standard deviation weekend": 15,  # Standard deviation of distance travelled on a weekend in
                                "min distance": 30,  # Minimum distance travelled in km
                                "max distance": 300,  # Maximum distance travelled in km  
                                "min distance per hour": 1,  # Minimum distance travelled per hour in km
                                "max distance per hour": 50,  # Maximum distance travelled per hour in km
                                "average stops": 30,  # Average number of stops per day
                                "standard deviation stops": 10  # Standard deviation of number of stops per                  
                                },
              
              "Schedule name": 'schedule_Mathem' ##CHANGE # Name of the schedule
                }

# %%
# Schedule arguments - adjust settings if necessary

#Postnord

Postnord_sch_config = {"Vehicles number": 30,  ##CHANGE # Number of vehicles in the fleet (You can choose the number of vehicles you want to generate the schedule for, but it needs to be the same has env_config)
              
              "Type of schedule": {"type a": 30, "type b": 0, "type c": 0},  ##CHANGE NUMBER OF EV # Type A, which consists of a continuous schedule, and Type B, which includes breaks, going to the distribution terminal durind the day.
              
              #type C is Custom Schedule is when you need to createq your own schedule, and it is defined below.
                            
              # Type C is Custom Schedule that needs to be define here:
              
              "Custom Schedule": {"average departure weekday": 8,  # Average departure time on a weekday in hours (0-23)
                                  "std deviation departure weekday": 1,  # Standard deviation of departure time on a weekday in hours
                                  "average return weekday": 18,  # Average return time on a weekday in hours (0-23)
                                  "std deviation return weekday": 1,  # Standard deviation of return time on a weekday in hours
                                  "average departure weekend": 9,  # Average departure time on a weekend in hours (0-23)
                                  "std deviation departure weekend": 1,  # Standard deviation of departure time on a weekend in hours
                                  "average return weekend": 19,  # Average return time on a weekend in hours (0-23)
                                  "std deviation return weekend": 1,  # Standard deviation of return time on a weekend in hours
                                  "minimum departure": 6,  # Minimum departure time in hours (0-23)
                                  "maximum departure": 11,  # Maximum departure time in hours (0-23)
                                  "minimum return": 18,  # Minimum return time in hours (0-23)
                                  "maximum return": 22  # Maximum return time in hours (0-23)
                                  },
              
              "Type of vehicle": {"Renault":6, "Toyota":24},  # Renault or Toyota ##CHANGE COMBINATION
              
              "Company type": companytype.Mail, ##CHANGE # Types of company: Distribution, LineHaul, CraftServWithGoods, CraftServWithoutGoods, Food, Mail, Building, Highdistance, Generalcargo, Nogoodsm, Custom
              
              #"Company type":Custom,  # Custom company type, if you want to generate a custom schedule with your own distance and stops parameters
              "Custom Distance": {"average weekday":120,  # Average distance travelled on a weekday in km
                                "average weekend": 70,  # Average distance travelled on a weekend in km 
                                "standard deviation weekday": 15,  # Standard deviation of distance travelled on a weekday in km
                                "standard deviation weekend": 15,  # Standard deviation of distance travelled on a weekend in
                                "min distance": 30,  # Minimum distance travelled in km
                                "max distance": 300,  # Maximum distance travelled in km  
                                "min distance per hour": 1,  # Minimum distance travelled per hour in km
                                "max distance per hour": 50,  # Maximum distance travelled per hour in km
                                "average stops": 30,  # Average number of stops per day
                                "standard deviation stops": 10  # Standard deviation of number of stops per                  
                                },
              
              "Schedule name": 'schedule_Postnord' ##CHANGE # Name of the schedule
                }

# %%
# Schedule arguments - adjust settings if necessary
Airmee_sch_config = {"Vehicles number":12,  ##CHANGE # Number of vehicles in the fleet (You can choose the number of vehicles you want to generate the schedule for, but it needs to be the same has env_config)
              
              "Type of schedule": {"type a":12, "type b": 0, "type c": 0},  ##CHANGE NUMBER OF EV # Type A, which consists of a continuous schedule, and Type B, which includes breaks, going to the distribution terminal durind the day.
              
              #type C is Custom Schedule is when you need to createq your own schedule, and it is defined below.
                            
              # Type C is Custom Schedule that needs to be define here:
              
              "Custom Schedule": {"average departure weekday": 8,  # Average departure time on a weekday in hours (0-23)
                                  "std deviation departure weekday": 1,  # Standard deviation of departure time on a weekday in hours
                                  "average return weekday": 18,  # Average return time on a weekday in hours (0-23)
                                  "std deviation return weekday": 1,  # Standard deviation of return time on a weekday in hours
                                  "average departure weekend": 9,  # Average departure time on a weekend in hours (0-23)
                                  "std deviation departure weekend": 1,  # Standard deviation of departure time on a weekend in hours
                                  "average return weekend": 19,  # Average return time on a weekend in hours (0-23)
                                  "std deviation return weekend": 1,  # Standard deviation of return time on a weekend in hours
                                  "minimum departure": 6,  # Minimum departure time in hours (0-23)
                                  "maximum departure": 11,  # Maximum departure time in hours (0-23)
                                  "minimum return": 18,  # Minimum return time in hours (0-23)
                                  "maximum return": 22  # Maximum return time in hours (0-23)
                                  },

              "Type of vehicle": {"Renault": 6, "Toyota": 6},  # Renault or Toyota ##CHANGE COMBINATION

              "Company type": companytype.Mail, ##CHANGE # Types of company: Distribution, LineHaul, CraftServWithGoods, CraftServWithoutGoods, Food, Mail, Building, Highdistance, Generalcargo, Nogoodsm, Custom
              
              #"Company type":Custom,  # Custom company type, if you want to generate a custom schedule with your own distance and stops parameters
              "Custom Distance": {"average weekday":120,  # Average distance travelled on a weekday in km
                                "average weekend": 70,  # Average distance travelled on a weekend in km 
                                "standard deviation weekday": 15,  # Standard deviation of distance travelled on a weekday in km
                                "standard deviation weekend": 15,  # Standard deviation of distance travelled on a weekend in
                                "min distance": 30,  # Minimum distance travelled in km
                                "max distance": 300,  # Maximum distance travelled in km  
                                "min distance per hour": 1,  # Minimum distance travelled per hour in km
                                "max distance per hour": 50,  # Maximum distance travelled per hour in km
                                "average stops": 30,  # Average number of stops per day
                                "standard deviation stops": 10  # Standard deviation of number of stops per                  
                                },
              
              "Schedule name": 'schedule_Airmee' ##CHANGE # Name of the schedule
                }

# %% [markdown]
# ## 1.3. Schedule Generation

# %% [markdown]
# Define the vehicle fleet and type of schedule to generate in the following cell. It is possible to duplicate the cell and generate schedules for differents vehicle fleets.

# %%
schedule_Postnord = generate_schedules(env_config, Postnord_sch_config,)
schedule_ICA = generate_schedules(env_config, ICA_sch_config)
schedule_Mathem = generate_schedules(env_config, Mathem_sch_config)
schedule_Airmee = generate_schedules(env_config, Airmee_sch_config)

# %% [markdown]
# ### Save parameters files in CVS

# %%
# Save individual files for each parameter for all schedules
parameters = ['Distance_km', 'Consumption_kWh', 'Consumption_km', 'Location', 'ChargingStation', 'PowerRating_kW', 'ScheduleType', 'consumption_factor']

# List of DataFrames and their corresponding names
schedules = [schedule_Airmee, schedule_ICA, schedule_Mathem, schedule_Postnord]
schedule_names = ['schedule_Airmee', 'schedule_ICA', 'schedule_Mathem', 'schedule_Postnord']

for schedule_df, schedule_name in zip(schedules, schedule_names):
    for parameter in parameters:
        # Pivot the table for the current parameter
        pivoted_schedule = schedule_df.pivot_table(
            index='date', 
            columns='VehicleID', 
            values=parameter, 
            aggfunc='first'
        )

        # Flatten the multi-index columns
        pivoted_schedule.columns = [f'{parameter}_Vehicle_{vehicle}' for vehicle in pivoted_schedule.columns]
        
        # Reset the index to bring 'date' as a column
        pivoted_schedule.reset_index(inplace=True)
        
        # Folder name
        folder_name = f'{schedule_name}'

        # Create and check on the folder Output in data folder in the project root
        output_folder = os.path.join(project_root, 'data', 'Output', folder_name)
        
        if not os.path.exists(output_folder):
            os.makedirs(output_folder)
        
        # Save each parameter to a separate CSV file in the output_folder
        file_name = os.path.join(output_folder, f'{schedule_name}_all_vehicles_{parameter}.csv')
        pivoted_schedule.to_csv(file_name, index=False)

# %%
print(schedule_Airmee)
# Out:
#                     date  Distance_km  Consumption_kWh  Consumption_km  \
# 0    2026-01-01 00:00:00          0.0              0.0             0.0
# 1    2026-01-01 01:00:00          0.0              0.0             0.0
# 2    2026-01-01 02:00:00          0.0              0.0             0.0
# 3    2026-01-01 03:00:00          0.0              0.0             0.0
# 4    2026-01-01 04:00:00          0.0              0.0             0.0
# ...                  ...          ...              ...             ...
# 4027 2026-01-14 19:00:00          0.0              0.0             0.0
# 4028 2026-01-14 20:00:00          0.0              0.0             0.0
# 4029 2026-01-14 21:00:00          0.0              0.0             0.0
# 4030 2026-01-14 22:00:00          0.0              0.0             0.0
# 4031 2026-01-14 23:00:00          0.0              0.0             0.0
#
#      Location ChargingStation  ID  PowerRating_kW  consumption_factor  \
# 0           1               1   0              80                 1.0
# 1           1               1   0              80                 1.0
# 2           1               1   0              80                 1.0
# 3           1               1   0              80                 1.0
# 4           1               1   0              80                 1.0
# ...       ...             ...  ..             ...                 ...
# 4027        1               1  11             100                 1.0
# 4028        1               1  11             100                 1.0
# 4029        1               1  11             100                 1.0
# 4030        1               1  11             100                 1.0
# 4031        1               1  11             100                 1.0
#
#      VehicleID ScheduleType VehicleType CompanyType
# 0            0        Typea     Renault        Mail
# 1            0        Typea     Renault        Mail
# 2            0        Typea     Renault        Mail
# 3            0        Typea     Renault        Mail
# 4            0        Typea     Renault        Mail
# ...        ...          ...         ...         ...
# 4027        11        Typea      Toyota        Mail
# 4028        11        Typea      Toyota        Mail
# 4029        11        Typea      Toyota        Mail
# 4030        11        Typea      Toyota        Mail
# 4031        11        Typea      Toyota        Mail
#
# [4032 rows x 13 columns]

# %% [markdown]
# ## 1.4. Schedules post-processing and visualisation

# %% [markdown]
# ### Graphs generation per schedule
# If you have more than one type of fleet, just need to add the folder name in the next cell.

# %%
import os
from pathlib import Path

folders = ["schedule_Airmee", "schedule_ICA", "schedule_Mathem", "schedule_Postnord"]

real_notebook_dir = Path(os.getcwd()).parent

for folder in folders:
    schedule_name = folder # folder.split("_")[1]
    output_folder = os.path.join(real_notebook_dir, 'data', 'Output', folder)
    distance_file_path = os.path.join(output_folder, f'{schedule_name}_all_vehicles_Distance_km.csv')
    charging_file_path = os.path.join(output_folder, f'{schedule_name}_all_vehicles_ChargingStation.csv')
    consumption_file_path = os.path.join(output_folder, f'{schedule_name}_all_vehicles_Consumption_kWh.csv')

    print("\n", folder)
    print()
    generate_graphs(distance_file_path, charging_file_path, consumption_file_path, folder, output_folder)
# Out:
#  schedule_Airmee
#  schedule_ICA
#  schedule_Mathem
#  schedule_Postnord
